# %% [markdown]
# # Highway Vehicle Counting Practice Exercise

# %% [markdown]
# In this exercise, you will use the YOLO (You Only Look Once) object detection model to analyze a video of highway traffic.
# Your task is to count the number of cars that are leaving the highway (coming toward the camera) on the right side and the number of cars that are joining the road on the left side. The video can be found under `Datasets/Example.mp4`.
#
# ## Objectives
# - Load and process a video using OpenCV.
# - Use the YOLO model to detect vehicles in each frame.
# - Use OpenCV to manulate the video.
# - Track vehicles as they move through the video frames.
# - Count the number of vehicles leaving the highway on the right side.
# - Count the number of vehicles joining the road on the left side.

# %% [markdown]
# ## Setup Environment

# %% [markdown]
# Before you begin, ensure you have the necessary libraries installed. You will need `opencv`, and `ultralytics` among others.
# If these are not installed, you should install them.

# %%
# %%capture
pip install opencv-python ultralytics numpy

# %%
from ultralytics import YOLO
import cv2
import numpy as np

# %% [markdown]
# ## Load the YOLO Model

# %% [markdown]
# You will first need to load the YOLO model. You can use a pre-trained YOLO model for this task.
# Write the code to load the YOLO model below:

# %%
model = YOLO('yolov8n.pt')

# %% [markdown]
# ## Prepare the Video Capture

# %% [markdown]
# Create a variable to capture the video frames, you can use `cv2.VideoCapture()` to achive this.

# %%
video_path = '/content/Example.mp4'
cap = cv2.VideoCapture(video_path)

# %% [markdown]
# ## Get Video Information

# %% [markdown]
# You can use `cv2` library to get these information fro the `VideoCapture()` variable you created to extract these information:
# * `height`: Video's height.
# * `width`: Video's width.
# * `fps`: Video's frames.

# %%
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %% [markdown]
# ## Prepare Video Writer to Store the Output

# %% [markdown]
# Create a variable that uses `cv2.VideoCapture()` to save the video with the bounding boxes and the counted cars on both sides. You will need to make the video with the same `fps`, `width`, `height`, and specify the codec and output path of the video.

# %%
output_path = 'output_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# %% [markdown]
# ## Process Video Frames and Identify Vehicles on the Right and Left Sides

# %% [markdown]
# For each frame in the video, use the YOLO model to detect and track vehicles. You'll need to write a loop that processes each frame and applies the YOLO model.
# In each frame, after detecting the vehicles, determine whether they are on the left or right side of the highway.
# You can use the position of the bounding boxes provided by YOLO to do this.
# * The video should display bounding boxes around the detected objects.
# * The video should display the confidence along side with the object id and class id of each detected and tracked object.
# * The video display the number of vehicles on the left side.
# * The video display the number of vehicles on the right side.
# * The video should display the line in which you counted the objects that have crossed it and counted.

# %%
# Here is about define counters and line position
left_count = 0
right_count = 0
line_y = height // 2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Here is about perform object detection
    results = model(frame)

    # Here is about process the results
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
            class_id = int(box.cls)
            confidence = box.conf.item()

            # Here is about determine the vehicle position
            if (x1 + x2) / 2 > width // 2:
                right_count += 1
                color = (0, 0, 255)
            else:
                left_count += 1
                color = (0, 255, 0)

            # Here ia about draw bounding box and label
            label = f'Class: {class_id} Conf: {confidence:.2f}'
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Here is about draw the line and display counts
    cv2.line(frame, (0, line_y), (width, line_y), (255, 0, 0), 2)
    cv2.putText(frame, f'Left Count: {left_count}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f'Right Count: {right_count}', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Here is about write frame to output video
    out.write(frame)

# Here is about release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 160.9ms
# Speed: 5.0ms preprocess, 160.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 282.5ms
# Speed: 6.2ms preprocess, 282.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 364.7ms
# Speed: 6.6ms preprocess, 364.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 481.7ms
# Speed: 5.9ms preprocess, 481.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 622.4ms
# Speed: 12.0ms preprocess, 622.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 633.6ms
# Speed: 11.1ms preprocess, 633.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 668.1ms
# Speed: 3.5ms preprocess, 668.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 448.7ms
# Speed: 27.7ms preprocess, 448.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 595.8ms
# Speed: 10.9ms preprocess, 595.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 523.1ms
# Speed: 7.9ms preprocess, 523.1ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 353.0ms
# Speed: 6.6ms preprocess, 353.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 454.6ms
# Speed: 4.7ms preprocess, 454.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 310.3ms
# Speed: 4.9ms preprocess, 310.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 293.8ms
# Speed: 3.0ms preprocess, 293.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 276.6ms
# Speed: 4.9ms preprocess, 276.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 490.0ms
# Speed: 4.8ms preprocess, 490.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 1 truck, 316.5ms
# Speed: 36.7ms preprocess, 316.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 train, 1 truck, 262.3ms
# Speed: 5.2ms preprocess, 262.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 2 trucks, 313.9ms
# Speed: 5.0ms preprocess, 313.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 261.6ms
# Speed: 4.9ms preprocess, 261.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 train, 1 truck, 373.8ms
# Speed: 4.9ms preprocess, 373.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 168.3ms
# Speed: 5.4ms preprocess, 168.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 161.3ms
# Speed: 4.5ms preprocess, 161.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 159.1ms
# Speed: 5.9ms preprocess, 159.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 1 truck, 160.7ms
# Speed: 4.5ms preprocess, 160.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 184.9ms
# Speed: 3.8ms preprocess, 184.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 167.5ms
# Speed: 5.2ms preprocess, 167.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 1 truck, 165.3ms
# Speed: 4.7ms preprocess, 165.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 157.6ms
# Speed: 6.0ms preprocess, 157.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 161.8ms
# Speed: 3.3ms preprocess, 161.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 160.5ms
# Speed: 4.7ms preprocess, 160.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 1 truck, 161.4ms
# Speed: 5.1ms preprocess, 161.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 168.1ms
# Speed: 5.2ms preprocess, 168.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 155.1ms
# Speed: 5.2ms preprocess, 155.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 167.6ms
# Speed: 4.8ms preprocess, 167.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 170.3ms
# Speed: 5.4ms preprocess, 170.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 165.0ms
# Speed: 6.3ms preprocess, 165.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 1 truck, 171.7ms
# Speed: 5.3ms preprocess, 171.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 1 truck, 158.3ms
# Speed: 4.7ms preprocess, 158.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 165.1ms
# Speed: 5.0ms preprocess, 165.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 174.8ms
# Speed: 4.4ms preprocess, 174.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 168.2ms
# Speed: 5.8ms preprocess, 168.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 173.7ms
# Speed: 5.6ms preprocess, 173.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 159.5ms
# Speed: 4.5ms preprocess, 159.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 153.0ms
# Speed: 5.5ms preprocess, 153.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 buss, 1 train, 3 trucks, 161.1ms
# Speed: 5.7ms preprocess, 161.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 176.7ms
# Speed: 5.0ms preprocess, 176.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 177.1ms
# Speed: 5.5ms preprocess, 177.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 160.5ms
# Speed: 4.3ms preprocess, 160.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 246.1ms
# Speed: 4.6ms preprocess, 246.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 271.9ms
# Speed: 5.0ms preprocess, 271.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 250.0ms
# Speed: 7.3ms preprocess, 250.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 245.6ms
# Speed: 4.9ms preprocess, 245.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 3 trucks, 279.4ms
# Speed: 3.0ms preprocess, 279.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 3 trucks, 253.2ms
# Speed: 2.9ms preprocess, 253.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 268.4ms
# Speed: 2.9ms preprocess, 268.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 258.2ms
# Speed: 4.9ms preprocess, 258.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 3 trucks, 255.1ms
# Speed: 6.0ms preprocess, 255.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 3 trucks, 276.9ms
# Speed: 4.6ms preprocess, 276.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 3 trucks, 253.2ms
# Speed: 4.8ms preprocess, 253.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 3 trucks, 269.3ms
# Speed: 5.1ms preprocess, 269.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 3 trucks, 165.2ms
# Speed: 4.7ms preprocess, 165.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 3 trucks, 172.1ms
# Speed: 4.9ms preprocess, 172.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 158.2ms
# Speed: 6.9ms preprocess, 158.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 182.0ms
# Speed: 5.8ms preprocess, 182.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 168.2ms
# Speed: 4.9ms preprocess, 168.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 165.6ms
# Speed: 5.2ms preprocess, 165.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 187.9ms
# Speed: 4.5ms preprocess, 187.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 2 trucks, 162.1ms
# Speed: 4.5ms preprocess, 162.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 186.0ms
# Speed: 5.3ms preprocess, 186.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 161.1ms
# Speed: 4.4ms preprocess, 161.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 2 trucks, 165.1ms
# Speed: 5.2ms preprocess, 165.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 2 trains, 2 trucks, 180.3ms
# Speed: 6.2ms preprocess, 180.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 161.6ms
# Speed: 4.4ms preprocess, 161.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 182.5ms
# Speed: 4.7ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 177.4ms
# Speed: 4.9ms preprocess, 177.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 168.7ms
# Speed: 4.5ms preprocess, 168.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 173.0ms
# Speed: 4.4ms preprocess, 173.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 1 truck, 164.0ms
# Speed: 5.4ms preprocess, 164.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 1 truck, 177.5ms
# Speed: 4.5ms preprocess, 177.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 154.5ms
# Speed: 5.0ms preprocess, 154.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 164.0ms
# Speed: 5.4ms preprocess, 164.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 166.7ms
# Speed: 5.5ms preprocess, 166.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 171.9ms
# Speed: 6.9ms preprocess, 171.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 176.7ms
# Speed: 5.0ms preprocess, 176.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 171.9ms
# Speed: 4.6ms preprocess, 171.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 train, 2 trucks, 177.3ms
# Speed: 5.9ms preprocess, 177.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 175.8ms
# Speed: 5.8ms preprocess, 175.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 186.5ms
# Speed: 3.6ms preprocess, 186.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 200.7ms
# Speed: 5.8ms preprocess, 200.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 167.7ms
# Speed: 6.0ms preprocess, 167.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 174.8ms
# Speed: 4.5ms preprocess, 174.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 161.4ms
# Speed: 5.3ms preprocess, 161.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 162.3ms
# Speed: 5.2ms preprocess, 162.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 192.4ms
# Speed: 5.4ms preprocess, 192.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 3 trucks, 182.9ms
# Speed: 5.4ms preprocess, 182.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 3 trucks, 175.4ms
# Speed: 4.2ms preprocess, 175.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 209.5ms
# Speed: 6.5ms preprocess, 209.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 195.0ms
# Speed: 6.3ms preprocess, 195.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 168.0ms
# Speed: 7.0ms preprocess, 168.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 163.1ms
# Speed: 6.6ms preprocess, 163.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 167.1ms
# Speed: 5.1ms preprocess, 167.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 1 truck, 173.6ms
# Speed: 4.9ms preprocess, 173.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 190.6ms
# Speed: 5.9ms preprocess, 190.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 171.1ms
# Speed: 5.5ms preprocess, 171.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 161.8ms
# Speed: 6.5ms preprocess, 161.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 168.0ms
# Speed: 4.8ms preprocess, 168.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 174.8ms
# Speed: 5.0ms preprocess, 174.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 185.0ms
# Speed: 5.7ms preprocess, 185.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 169.1ms
# Speed: 5.3ms preprocess, 169.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 255.0ms
# Speed: 2.9ms preprocess, 255.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 245.5ms
# Speed: 4.8ms preprocess, 245.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 265.2ms
# Speed: 7.9ms preprocess, 265.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 245.1ms
# Speed: 4.8ms preprocess, 245.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 259.8ms
# Speed: 9.1ms preprocess, 259.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 262.2ms
# Speed: 5.1ms preprocess, 262.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 251.1ms
# Speed: 5.1ms preprocess, 251.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 243.7ms
# Speed: 4.9ms preprocess, 243.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 249.8ms
# Speed: 4.5ms preprocess, 249.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 261.1ms
# Speed: 5.4ms preprocess, 261.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 268.1ms
# Speed: 5.3ms preprocess, 268.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 263.9ms
# Speed: 4.6ms preprocess, 263.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 261.6ms
# Speed: 5.7ms preprocess, 261.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 168.0ms
# Speed: 5.0ms preprocess, 168.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 165.5ms
# Speed: 5.6ms preprocess, 165.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 164.8ms
# Speed: 5.3ms preprocess, 164.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 198.6ms
# Speed: 4.9ms preprocess, 198.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 188.1ms
# Speed: 4.5ms preprocess, 188.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 168.6ms
# Speed: 5.3ms preprocess, 168.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 166.4ms
# Speed: 5.5ms preprocess, 166.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 162.8ms
# Speed: 5.3ms preprocess, 162.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 170.3ms
# Speed: 5.4ms preprocess, 170.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 194.9ms
# Speed: 5.5ms preprocess, 194.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 162.9ms
# Speed: 5.7ms preprocess, 162.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 161.2ms
# Speed: 3.8ms preprocess, 161.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 160.0ms
# Speed: 5.5ms preprocess, 160.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 173.0ms
# Speed: 4.6ms preprocess, 173.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 167.1ms
# Speed: 5.5ms preprocess, 167.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 163.5ms
# Speed: 7.3ms preprocess, 163.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 166.8ms
# Speed: 4.7ms preprocess, 166.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 160.2ms
# Speed: 5.5ms preprocess, 160.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 167.6ms
# Speed: 5.4ms preprocess, 167.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 176.8ms
# Speed: 6.7ms preprocess, 176.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 1 truck, 168.9ms
# Speed: 5.0ms preprocess, 168.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 163.4ms
# Speed: 5.9ms preprocess, 163.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 167.0ms
# Speed: 4.3ms preprocess, 167.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 167.1ms
# Speed: 4.8ms preprocess, 167.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 184.0ms
# Speed: 5.4ms preprocess, 184.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 173.5ms
# Speed: 4.4ms preprocess, 173.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 170.3ms
# Speed: 4.9ms preprocess, 170.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 181.0ms
# Speed: 6.5ms preprocess, 181.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 192.3ms
# Speed: 5.7ms preprocess, 192.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 170.9ms
# Speed: 5.6ms preprocess, 170.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 197.4ms
# Speed: 8.0ms preprocess, 197.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 169.4ms
# Speed: 4.5ms preprocess, 169.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 177.3ms
# Speed: 4.9ms preprocess, 177.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 207.0ms
# Speed: 6.4ms preprocess, 207.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 1 truck, 182.2ms
# Speed: 6.9ms preprocess, 182.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 1 truck, 168.9ms
# Speed: 5.1ms preprocess, 168.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 169.6ms
# Speed: 5.4ms preprocess, 169.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 173.8ms
# Speed: 7.2ms preprocess, 173.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 175.1ms
# Speed: 6.5ms preprocess, 175.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 173.9ms
# Speed: 5.1ms preprocess, 173.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 158.6ms
# Speed: 5.8ms preprocess, 158.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 156.8ms
# Speed: 5.3ms preprocess, 156.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 161.2ms
# Speed: 5.2ms preprocess, 161.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 172.6ms
# Speed: 8.9ms preprocess, 172.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 165.3ms
# Speed: 5.7ms preprocess, 165.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 173.2ms
# Speed: 5.3ms preprocess, 173.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 166.0ms
# Speed: 5.8ms preprocess, 166.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 159.5ms
# Speed: 4.8ms preprocess, 159.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 181.6ms
# Speed: 5.3ms preprocess, 181.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 264.6ms
# Speed: 8.1ms preprocess, 264.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 249.2ms
# Speed: 4.7ms preprocess, 249.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 272.1ms
# Speed: 6.4ms preprocess, 272.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 1 truck, 245.0ms
# Speed: 5.8ms preprocess, 245.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 265.3ms
# Speed: 6.0ms preprocess, 265.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 243.3ms
# Speed: 4.7ms preprocess, 243.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 260.0ms
# Speed: 6.5ms preprocess, 260.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 238.9ms
# Speed: 6.1ms preprocess, 238.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 259.6ms
# Speed: 4.8ms preprocess, 259.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 268.3ms
# Speed: 9.3ms preprocess, 268.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 259.6ms
# Speed: 4.9ms preprocess, 259.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 256.6ms
# Speed: 4.9ms preprocess, 256.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 203.3ms
# Speed: 5.5ms preprocess, 203.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 181.9ms
# Speed: 5.3ms preprocess, 181.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 167.9ms
# Speed: 5.8ms preprocess, 167.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 156.1ms
# Speed: 5.8ms preprocess, 156.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 180.4ms
# Speed: 5.7ms preprocess, 180.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 179.7ms
# Speed: 6.1ms preprocess, 179.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 194.8ms
# Speed: 9.8ms preprocess, 194.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 176.9ms
# Speed: 6.5ms preprocess, 176.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 176.8ms
# Speed: 7.3ms preprocess, 176.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 train, 181.7ms
# Speed: 6.8ms preprocess, 181.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 168.8ms
# Speed: 4.9ms preprocess, 168.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 169.7ms
# Speed: 4.8ms preprocess, 169.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 164.4ms
# Speed: 4.7ms preprocess, 164.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 153.5ms
# Speed: 6.8ms preprocess, 153.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 177.2ms
# Speed: 4.6ms preprocess, 177.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 167.2ms
# Speed: 4.5ms preprocess, 167.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 164.8ms
# Speed: 5.6ms preprocess, 164.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 169.8ms
# Speed: 5.0ms preprocess, 169.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 162.3ms
# Speed: 6.3ms preprocess, 162.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 177.6ms
# Speed: 5.6ms preprocess, 177.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 168.7ms
# Speed: 5.2ms preprocess, 168.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 168.2ms
# Speed: 4.7ms preprocess, 168.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 164.5ms
# Speed: 4.9ms preprocess, 164.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 161.3ms
# Speed: 6.4ms preprocess, 161.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 164.7ms
# Speed: 4.7ms preprocess, 164.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 171.2ms
# Speed: 6.3ms preprocess, 171.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 168.0ms
# Speed: 5.2ms preprocess, 168.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 162.2ms
# Speed: 5.5ms preprocess, 162.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 165.8ms
# Speed: 6.0ms preprocess, 165.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 161.4ms
# Speed: 5.1ms preprocess, 161.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 176.2ms
# Speed: 5.0ms preprocess, 176.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 174.4ms
# Speed: 4.6ms preprocess, 174.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 158.9ms
# Speed: 5.4ms preprocess, 158.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 161.0ms
# Speed: 5.7ms preprocess, 161.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 166.2ms
# Speed: 5.1ms preprocess, 166.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 170.7ms
# Speed: 5.3ms preprocess, 170.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 175.5ms
# Speed: 6.5ms preprocess, 175.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 171.0ms
# Speed: 5.5ms preprocess, 171.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 167.0ms
# Speed: 4.9ms preprocess, 167.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 161.7ms
# Speed: 5.3ms preprocess, 161.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 177.2ms
# Speed: 4.8ms preprocess, 177.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 178.5ms
# Speed: 6.2ms preprocess, 178.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 161.8ms
# Speed: 5.4ms preprocess, 161.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 165.2ms
# Speed: 5.0ms preprocess, 165.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 160.9ms
# Speed: 4.5ms preprocess, 160.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 157.6ms
# Speed: 6.4ms preprocess, 157.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 198.0ms
# Speed: 4.1ms preprocess, 198.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 177.6ms
# Speed: 5.1ms preprocess, 177.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 164.0ms
# Speed: 5.1ms preprocess, 164.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 177.8ms
# Speed: 5.5ms preprocess, 177.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 1 truck, 214.6ms
# Speed: 5.4ms preprocess, 214.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 274.6ms
# Speed: 8.0ms preprocess, 274.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 251.5ms
# Speed: 2.8ms preprocess, 251.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 237.1ms
# Speed: 4.6ms preprocess, 237.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 257.4ms
# Speed: 5.0ms preprocess, 257.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 236.9ms
# Speed: 5.6ms preprocess, 236.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 238.6ms
# Speed: 4.6ms preprocess, 238.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 251.4ms
# Speed: 5.0ms preprocess, 251.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 255.1ms
# Speed: 5.2ms preprocess, 255.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 250.1ms
# Speed: 5.3ms preprocess, 250.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 246.9ms
# Speed: 4.7ms preprocess, 246.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 288.6ms
# Speed: 3.1ms preprocess, 288.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 1 truck, 235.0ms
# Speed: 4.8ms preprocess, 235.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 173.4ms
# Speed: 6.9ms preprocess, 173.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 167.4ms
# Speed: 7.4ms preprocess, 167.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 177.4ms
# Speed: 9.2ms preprocess, 177.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 184.2ms
# Speed: 5.9ms preprocess, 184.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 161.7ms
# Speed: 4.9ms preprocess, 161.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 160.9ms
# Speed: 5.0ms preprocess, 160.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 163.7ms
# Speed: 5.6ms preprocess, 163.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 180.4ms
# Speed: 4.0ms preprocess, 180.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 167.6ms
# Speed: 4.9ms preprocess, 167.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 161.1ms
# Speed: 5.5ms preprocess, 161.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 162.9ms
# Speed: 4.5ms preprocess, 162.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 157.6ms
# Speed: 4.6ms preprocess, 157.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 1 truck, 174.3ms
# Speed: 2.9ms preprocess, 174.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 161.1ms
# Speed: 3.1ms preprocess, 161.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 158.0ms
# Speed: 5.7ms preprocess, 158.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 157.2ms
# Speed: 4.7ms preprocess, 157.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 1 truck, 164.4ms
# Speed: 5.1ms preprocess, 164.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 1 truck, 198.2ms
# Speed: 4.7ms preprocess, 198.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 157.4ms
# Speed: 5.8ms preprocess, 157.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 178.2ms
# Speed: 4.5ms preprocess, 178.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 152.7ms
# Speed: 4.6ms preprocess, 152.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 159.3ms
# Speed: 5.5ms preprocess, 159.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 187.7ms
# Speed: 5.7ms preprocess, 187.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 161.3ms
# Speed: 5.2ms preprocess, 161.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 175.7ms
# Speed: 6.5ms preprocess, 175.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 156.8ms
# Speed: 5.6ms preprocess, 156.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 163.8ms
# Speed: 5.5ms preprocess, 163.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 179.9ms
# Speed: 5.3ms preprocess, 179.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 164.7ms
# Speed: 5.0ms preprocess, 164.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 178.9ms
# Speed: 5.4ms preprocess, 178.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 158.7ms
# Speed: 5.6ms preprocess, 158.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 3 trucks, 167.0ms
# Speed: 5.3ms preprocess, 167.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 3 trucks, 180.4ms
# Speed: 5.5ms preprocess, 180.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 169.4ms
# Speed: 5.8ms preprocess, 169.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 152.0ms
# Speed: 5.4ms preprocess, 152.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 173.4ms
# Speed: 6.9ms preprocess, 173.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 2 trucks, 165.5ms
# Speed: 5.5ms preprocess, 165.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 178.5ms
# Speed: 5.5ms preprocess, 178.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 158.2ms
# Speed: 5.4ms preprocess, 158.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 164.7ms
# Speed: 5.0ms preprocess, 164.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 179.0ms
# Speed: 6.1ms preprocess, 179.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 169.3ms
# Speed: 5.3ms preprocess, 169.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 184.6ms
# Speed: 6.1ms preprocess, 184.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 175.2ms
# Speed: 5.4ms preprocess, 175.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 177.0ms
# Speed: 7.1ms preprocess, 177.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 182.3ms
# Speed: 7.5ms preprocess, 182.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 172.3ms
# Speed: 6.2ms preprocess, 172.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 186.9ms
# Speed: 6.2ms preprocess, 186.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 173.1ms
# Speed: 7.7ms preprocess, 173.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 3 trucks, 191.7ms
# Speed: 5.4ms preprocess, 191.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 253.1ms
# Speed: 4.7ms preprocess, 253.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 3 trucks, 254.4ms
# Speed: 4.7ms preprocess, 254.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 250.7ms
# Speed: 4.9ms preprocess, 250.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 262.3ms
# Speed: 4.8ms preprocess, 262.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 3 trucks, 239.4ms
# Speed: 6.0ms preprocess, 239.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 252.3ms
# Speed: 5.6ms preprocess, 252.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 247.1ms
# Speed: 4.7ms preprocess, 247.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 264.9ms
# Speed: 4.7ms preprocess, 264.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 1 train, 2 trucks, 254.1ms
# Speed: 7.0ms preprocess, 254.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 3 trucks, 255.9ms
# Speed: 5.9ms preprocess, 255.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 275.7ms
# Speed: 4.5ms preprocess, 275.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 1 train, 2 trucks, 273.7ms
# Speed: 4.7ms preprocess, 273.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 3 trucks, 188.8ms
# Speed: 6.1ms preprocess, 188.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 3 trucks, 161.5ms
# Speed: 5.2ms preprocess, 161.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 1 train, 4 trucks, 164.9ms
# Speed: 5.0ms preprocess, 164.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 1 train, 3 trucks, 392.4ms
# Speed: 4.7ms preprocess, 392.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 4 trucks, 165.5ms
# Speed: 4.5ms preprocess, 165.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 4 trucks, 160.4ms
# Speed: 4.8ms preprocess, 160.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 3 trucks, 286.8ms
# Speed: 5.8ms preprocess, 286.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 1 train, 2 trucks, 216.3ms
# Speed: 2.9ms preprocess, 216.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 1 train, 1 truck, 163.1ms
# Speed: 5.9ms preprocess, 163.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 2 trucks, 164.1ms
# Speed: 4.6ms preprocess, 164.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 1 train, 1 truck, 412.0ms
# Speed: 4.7ms preprocess, 412.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 1 truck, 160.5ms
# Speed: 4.9ms preprocess, 160.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 2 trucks, 174.7ms
# Speed: 5.7ms preprocess, 174.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 162.1ms
# Speed: 4.8ms preprocess, 162.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 159.0ms
# Speed: 4.6ms preprocess, 159.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 2 trucks, 192.6ms
# Speed: 3.7ms preprocess, 192.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 2 trucks, 156.2ms
# Speed: 4.5ms preprocess, 156.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 163.6ms
# ...
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 243.3ms
# Speed: 4.7ms preprocess, 243.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 3 trucks, 261.2ms
# Speed: 4.6ms preprocess, 261.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 236.7ms
# Speed: 6.0ms preprocess, 236.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 227.2ms
# Speed: 6.2ms preprocess, 227.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 2 trains, 2 trucks, 239.2ms
# Speed: 4.9ms preprocess, 239.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 248.4ms
# Speed: 6.4ms preprocess, 248.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 245.1ms
# Speed: 4.7ms preprocess, 245.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 237.2ms
# Speed: 4.6ms preprocess, 237.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 1 truck, 249.7ms
# Speed: 4.8ms preprocess, 249.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 1 truck, 256.5ms
# Speed: 4.7ms preprocess, 256.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 274.7ms
# Speed: 2.8ms preprocess, 274.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 250.5ms
# Speed: 5.7ms preprocess, 250.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 1 truck, 232.2ms
# Speed: 5.0ms preprocess, 232.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 buss, 1 train, 2 trucks, 162.0ms
# Speed: 6.8ms preprocess, 162.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 161.8ms
# Speed: 6.3ms preprocess, 161.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 157.9ms
# Speed: 5.6ms preprocess, 157.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 3 trucks, 156.7ms
# Speed: 6.4ms preprocess, 156.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 2 trucks, 187.0ms
# Speed: 5.0ms preprocess, 187.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 2 trucks, 157.5ms
# Speed: 6.0ms preprocess, 157.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 3 trucks, 160.2ms
# Speed: 5.1ms preprocess, 160.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 160.7ms
# Speed: 6.2ms preprocess, 160.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 172.5ms
# Speed: 6.7ms preprocess, 172.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 178.2ms
# Speed: 7.5ms preprocess, 178.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 168.4ms
# Speed: 5.4ms preprocess, 168.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 3 trucks, 164.9ms
# Speed: 5.6ms preprocess, 164.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 train, 3 trucks, 165.7ms
# Speed: 7.2ms preprocess, 165.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 train, 3 trucks, 163.1ms
# Speed: 4.7ms preprocess, 163.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 train, 3 trucks, 160.1ms
# Speed: 4.7ms preprocess, 160.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 train, 3 trucks, 166.0ms
# Speed: 8.8ms preprocess, 166.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 3 trucks, 153.4ms
# Speed: 5.5ms preprocess, 153.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 2 trucks, 165.2ms
# Speed: 4.8ms preprocess, 165.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 train, 3 trucks, 167.7ms
# Speed: 4.9ms preprocess, 167.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 buss, 1 train, 3 trucks, 172.1ms
# Speed: 7.0ms preprocess, 172.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 172.1ms
# Speed: 6.7ms preprocess, 172.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 158.8ms
# Speed: 6.2ms preprocess, 158.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 159.9ms
# Speed: 4.9ms preprocess, 159.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 170.4ms
# Speed: 5.0ms preprocess, 170.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 3 trucks, 159.5ms
# Speed: 4.9ms preprocess, 159.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 166.2ms
# Speed: 4.8ms preprocess, 166.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 159.9ms
# Speed: 4.4ms preprocess, 159.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 163.2ms
# Speed: 6.4ms preprocess, 163.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 159.4ms
# Speed: 5.3ms preprocess, 159.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 2 trucks, 164.6ms
# Speed: 5.3ms preprocess, 164.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 3 trucks, 171.2ms
# Speed: 5.8ms preprocess, 171.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 1 truck, 158.4ms
# Speed: 5.2ms preprocess, 158.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 156.7ms
# Speed: 4.7ms preprocess, 156.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 157.7ms
# Speed: 5.4ms preprocess, 157.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2 buss, 1 train, 167.4ms
# Speed: 5.3ms preprocess, 167.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 buss, 1 train, 157.6ms
# Speed: 5.4ms preprocess, 157.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 2 buss, 1 train, 159.8ms
# Speed: 4.7ms preprocess, 159.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 160.3ms
# Speed: 7.1ms preprocess, 160.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 158.8ms
# Speed: 5.6ms preprocess, 158.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 177.8ms
# Speed: 5.9ms preprocess, 177.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 155.3ms
# Speed: 6.6ms preprocess, 155.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 171.3ms
# Speed: 3.7ms preprocess, 171.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 158.6ms
# Speed: 6.0ms preprocess, 158.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 158.2ms
# Speed: 5.5ms preprocess, 158.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 175.8ms
# Speed: 4.7ms preprocess, 175.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 161.0ms
# Speed: 4.8ms preprocess, 161.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 174.4ms
# Speed: 4.9ms preprocess, 174.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 161.0ms
# Speed: 7.0ms preprocess, 161.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 2 trucks, 160.2ms
# Speed: 4.5ms preprocess, 160.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 2 trucks, 224.4ms
# Speed: 5.3ms preprocess, 224.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 2 trucks, 246.1ms
# Speed: 5.4ms preprocess, 246.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 2 trucks, 250.8ms
# Speed: 5.0ms preprocess, 250.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 train, 1 truck, 257.5ms
# Speed: 5.0ms preprocess, 257.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 1 truck, 240.1ms
# Speed: 6.3ms preprocess, 240.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 1 truck, 248.4ms
# Speed: 3.1ms preprocess, 248.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 243.3ms
# Speed: 4.7ms preprocess, 243.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 2 trucks, 239.5ms
# Speed: 5.4ms preprocess, 239.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 254.0ms
# Speed: 8.7ms preprocess, 254.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 248.1ms
# Speed: 4.8ms preprocess, 248.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 251.8ms
# Speed: 4.8ms preprocess, 251.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 3 trucks, 255.2ms
# Speed: 4.7ms preprocess, 255.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 245.6ms
# Speed: 4.6ms preprocess, 245.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 231.0ms
# Speed: 6.2ms preprocess, 231.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 163.9ms
# Speed: 4.6ms preprocess, 163.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 154.5ms
# Speed: 5.3ms preprocess, 154.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 3 trucks, 158.7ms
# Speed: 6.2ms preprocess, 158.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 3 trucks, 155.0ms
# Speed: 6.9ms preprocess, 155.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 3 trucks, 165.0ms
# Speed: 6.2ms preprocess, 165.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 3 trucks, 172.5ms
# Speed: 5.4ms preprocess, 172.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 160.7ms
# Speed: 5.2ms preprocess, 160.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 159.3ms
# Speed: 5.4ms preprocess, 159.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 156.3ms
# Speed: 6.1ms preprocess, 156.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 3 trucks, 166.3ms
# Speed: 5.4ms preprocess, 166.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 174.7ms
# Speed: 5.0ms preprocess, 174.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 2 trucks, 158.8ms
# Speed: 7.2ms preprocess, 158.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 162.4ms
# Speed: 7.0ms preprocess, 162.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 158.3ms
# Speed: 5.5ms preprocess, 158.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 169.4ms
# Speed: 6.3ms preprocess, 169.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 3 trucks, 186.8ms
# Speed: 4.8ms preprocess, 186.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 157.1ms
# Speed: 4.7ms preprocess, 157.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 3 trucks, 157.8ms
# Speed: 5.1ms preprocess, 157.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 165.1ms
# Speed: 4.6ms preprocess, 165.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 180.8ms
# Speed: 5.8ms preprocess, 180.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 181.2ms
# Speed: 5.6ms preprocess, 181.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 179.7ms
# Speed: 7.4ms preprocess, 179.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 193.2ms
# Speed: 6.9ms preprocess, 193.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 175.0ms
# Speed: 5.7ms preprocess, 175.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 189.9ms
# Speed: 5.3ms preprocess, 189.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 173.8ms
# Speed: 6.6ms preprocess, 173.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 158.2ms
# Speed: 7.9ms preprocess, 158.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 162.7ms
# Speed: 5.5ms preprocess, 162.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 161.9ms
# Speed: 6.1ms preprocess, 161.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 181.1ms
# Speed: 6.4ms preprocess, 181.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Save and Submit Your Work

# %% [markdown]
# In the actual exam you will be asked to submit both the notebook and the output video
